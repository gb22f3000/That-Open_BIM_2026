# %% [markdown]
# # A Python-based Sketchpad - Part 1: Python Basics
#
# Learn Python fundamentals: variables, functions, errors, comments, and libraries (numpy, matplotlib).

# %% [markdown]
# ## Hello World!

# %%
text = "Hello world, you're beautiful"
print(text)
# Out:
# Hello world, you're beautiful

# %%
text2 = "and wise"
print(text, text2)
# Out:
# Hello world, you're beautiful and wise

# %%
print(text, text2, sep="; ")
# Out:
# Hello world, you're beautiful; and wise

# %%
print(text, text2, sep="; ", end="!")
# Out:
# Hello world, you're beautiful; and wise!

# %% [markdown]
# ## A Word on Errors

# %%
# Uncomment to see NameError:
# print(Hello)
print("Hello")
# Out:
# Hello

# %%
Hello = "Hello"
print(Hello)
# Out:
# Hello

# %% [markdown]
# ## Comments

# %%
# Define measures
a = 30  # age in years
l = 1.80  # height in meters
w = 80   # weight in kg
print("My age is", a, "[yr]")
print("My height is", l, "[m]")
print("My weight is", w, "[kg]")
# Out:
# My age is 30 [yr]
# My height is 1.8 [m]
# My weight is 80 [kg]

# %% [markdown]
# ## Libraries / Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
